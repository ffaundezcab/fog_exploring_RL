# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tql_r = pd.read_excel("results_TQL_random.xlsx")

# %%
tql_r
# Out:
#    final epsilon  mean return last 50 eps  final greedy eval return_mean  \
# 0           0.05                  -170.78                        -862.51
# 1           0.05                  -170.78                        -853.78
# 2           0.05                  -170.78                        -827.16
# 3           0.05                  -170.78                        -889.72
# 4           0.05                  -170.78                        -915.42
# 5           0.05                  -170.78                        -851.56
# 6           0.05                  -170.78                        -912.54
# 7           0.05                  -170.78                        -847.90
# 8           0.05                  -170.78                        -894.02
# 9           0.05                  -170.78                        -901.95
#
#    final greedy eval return_std  weight matrix shape  evaluation success rate  \
# 0                    322.012251                  NaN                     11.0
# ...
